# %%
import sys
print(sys.executable)

import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# c:\Users\Usuario\anaconda3\envs\proyectoIA_GPU\python.exe
# True
# NVIDIA GeForce GTX 1650 with Max-Q Design

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
data = data.to(device)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# ----> 2 model.to(device)
#       3 data = data.to(device)
#
# NameError: name 'model' is not defined

# %%
conda list | findstr cuda
# Out:
# cuda-cccl                 12.9.27                       0    nvidia
# cuda-cccl_win-64          12.9.27                       0    nvidia
# cuda-cudart               12.1.105                      0    nvidia
# cuda-cudart-dev           12.1.105                      0    nvidia
# cuda-cupti                12.1.105                      0    nvidia
# cuda-libraries            12.1.0                        0    nvidia
# cuda-libraries-dev        12.1.0                        0    nvidia
# cuda-nvrtc                12.1.105                      0    nvidia
# cuda-nvrtc-dev            12.1.105                      0    nvidia
# cuda-nvtx                 12.1.105                      0    nvidia
# cuda-opencl               12.9.19                       0    nvidia
# cuda-opencl-dev           12.9.19                       0    nvidia
# cuda-profiler-api         12.9.79                       0    nvidia
# cuda-runtime              12.1.0                        0    nvidia
# cuda-version              12.9                          3    nvidia
# pytorch                   2.5.1           py3.10_cuda12.1_cudnn9_0    pytorch
# pytorch-cuda              12.1                 hde6ce7c_6    pytorch
# pytorch-mutex             1.0                        cuda    pytorch
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch

print("Torch version:", torch.__version__)
print("CUDA disponible:", torch.cuda.is_available())
print("GPU detectada:", torch.cuda.get_device_name(0))
print("CUDA version usada por torch:", torch.version.cuda)
# Out:
# Torch version: 2.5.1
# CUDA disponible: True
# GPU detectada: NVIDIA GeForce GTX 1650 with Max-Q Design
# CUDA version usada por torch: 12.1

# %%
import torch
import time

device = torch.device("cuda")
x = torch.randn(10000, 10000, device=device)

torch.cuda.synchronize()
start = time.time()

y = x @ x

torch.cuda.synchronize()
end = time.time()

print("Tiempo GPU:", end - start)
# Out:
# Tiempo GPU: 2.5648083686828613
